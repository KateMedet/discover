# %% [markdown]
# <table style="border:2px solid white;" cellspacing="0" cellpadding="0" border-collapse: collapse; border-spacing: 0;>
#   <tr>
#     <th style="background-color:white"> <img src="media/CCAL.png" width=175 height=175></th>
#     <th style="background-color:white"> <img src="media/logoMoores.jpg" width=175 height=175></th>
#     <th style="background-color:white"> <img src="media/GP.png" width=200 height=200></th>
#     <th style="background-color:white"> <img src="media/Johns_Hopkins_School_of_Medicine.png" width=175 height=175></th>
#     <th style="background-color:white"> <img src="media/Broad.png" width=130 height=130></th>
#   </tr>
# </table>

# %% [markdown]
# <h1 align="center">DiSCovERing innovative therapies for rare tumors: Overview</h1>

# %% [markdown]
# <hr style="border: none; border-bottom: 3px solid #88BBEE;">
# ## 1. Set up notebook and import Computational Cancer Analysis Library ([CCAL](https://github.com/KwatME/ccal))

# %%
import sys
import os

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

os.chdir('/Users/kateme')

from ccal import ccal

matplotlib inline
mpl.rcParams['figure.figsize'] = (8, 5)
mpl.rcParams['figure.max_open_warning'] = 100

# %% [markdown]
# <hr style="border: none; border-top: 3px solid #88BBEE;">
# ## 2. Set input and result files/directories
# These are the files where the input expression data and the output signature files are stored

# %%
# !AUTOEXEC
# Make and show widget
task_view = task_manager.create_task_view(json.loads('''{"description":"","function_name":"just_return","returns":[{"description":"No description :(","label":"Value"}],"library_path":"/Users/kateme/simplex/","optional_args":[],"default_args":[],"library_name":"simplex","required_args":[{"label":"item","value":"","arg_name":"item","description":"No description :("}],"label":"Assign"}'''))
task_view.create()
# Out:
# Executing ...
# 	sys.path.insert(0, '/Users/kateme/simplex/')
# 	from simplex import just_return as function
# Processing arguments ...
#
# 	Executing <function just_return at 0x10482df28>:
# 		item = '/Users/kateme/discover/data/' (<class 'str'>)

# %%
# !AUTOEXEC
# Make and show widget
task_view = task_manager.create_task_view(json.loads('''{"description":"","function_name":"just_return","returns":[{"description":"No description :(","label":"Value"}],"library_path":"/Users/kateme/simplex/","optional_args":[],"default_args":[],"library_name":"simplex","required_args":[{"label":"item","value":"","arg_name":"item","description":"No description :("}],"label":"Assign"}'''))
task_view.create()
# Out:
# Executing ...
# 	sys.path.insert(0, '/Users/kateme/simplex/')
# 	from simplex import just_return as function
# Processing arguments ...
#
# 	Executing <function just_return at 0x10482df28>:
# 		item = '/Users/kateme/discover/results/' (<class 'str'>)

# %% [markdown]
# Here the expressional signatures are loaded

# %%
# !AUTOEXEC
# Make and show widget
task_view = task_manager.create_task_view(json.loads('''{"description":"","function_name":"read_gct","returns":[{"description":"No description :(","label":"Matrix"}],"library_path":"/Users/kateme/ccal/","optional_args":[],"default_args":[],"library_name":"ccal","required_args":[{"label":".GCT file","value":"","arg_name":"filepath","description":"No description :("}],"label":"Read .GCT File"}'''))
task_view.create()
# Out:
# Executing ...
# 	sys.path.insert(0, '/Users/kateme/ccal/')
# 	from ccal import read_gct as function
# Processing arguments ...
#
# 	Executing <function read_gct at 0x11a4901e0>:
# 		filepath = '/Users/kateme/discover/data/Sanger_Expression.out.SELECTED_TISSUES_PATHWAYS.gct' (<class 'str'>)

# %%
# !AUTOEXEC
# Make and show widget
task_view = task_manager.create_task_view(json.loads('''{"description":"","function_name":"read_gct","returns":[{"description":"No description :(","label":"Matrix"}],"library_path":"/Users/kateme/ccal/","optional_args":[],"default_args":[],"library_name":"ccal","required_args":[{"label":".GCT file","value":"","arg_name":"filepath","description":"No description :("}],"label":"Read .GCT File"}'''))
task_view.create()
# Out:
# Executing ...
# 	sys.path.insert(0, '/Users/kateme/ccal/')
# 	from ccal import read_gct as function
# Processing arguments ...
#
# 	Executing <function read_gct at 0x11a4901e0>:
# 		filepath = '/Users/kateme/discover/data/CCLE_Expression_Entrez_2012-04-06_plus_Achilles.SELECTED_TISSUES_PATHWAYS.gct' (<class 'str'>)

# %%
sanger_signatures_hNSC150 = sanger_signatures.ix['hNSC_G3_150_UP']
ccle_signatures_hNSC150 = ccle_signatures.ix['hNSC_G3_150_UP']

# %% [markdown]
# Here the drug sensitivity data is loaded

# %%
# !AUTOEXEC
# Make and show widget
task_view = task_manager.create_task_view(json.loads('''{"description":"","function_name":"read_gct","returns":[{"description":"No description :(","label":"Matrix"}],"library_path":"/Users/kateme/ccal/","optional_args":[],"default_args":[],"library_name":"ccal","required_args":[{"label":".GCT file","value":"","arg_name":"filepath","description":"No description :("}],"label":"Read .GCT File"}'''))
task_view.create()
# Out:
# Executing ...
# 	sys.path.insert(0, '/Users/kateme/ccal/')
# 	from ccal import read_gct as function
# Processing arguments ...
#
# 	Executing <function read_gct at 0x11a4901e0>:
# 		filepath = '/Users/kateme/discover/data/CCLE_Drug_Sensitivity.gct' (<class 'str'>)

# %%
# !AUTOEXEC
# Make and show widget
task_view = task_manager.create_task_view(json.loads('''{"description":"","function_name":"read_gct","returns":[{"description":"No description :(","label":"Matrix"}],"library_path":"/Users/kateme/ccal/","optional_args":[],"default_args":[],"library_name":"ccal","required_args":[{"label":".GCT file","value":"","arg_name":"filepath","description":"No description :("}],"label":"Read .GCT File"}'''))
task_view.create()
# Out:
# Executing ...
# 	sys.path.insert(0, '/Users/kateme/ccal/')
# 	from ccal import read_gct as function
# Processing arguments ...
#
# 	Executing <function read_gct at 0x11a4901e0>:
# 		filepath = '/Users/kateme/discover/data/CTRPv2.2_2015_pub.gct' (<class 'str'>)

# %%
# !AUTOEXEC
# Make and show widget
task_view = task_manager.create_task_view(json.loads('''{"description":"","function_name":"read_gct","returns":[{"description":"No description :(","label":"Matrix"}],"library_path":"/Users/kateme/ccal/","optional_args":[],"default_args":[],"library_name":"ccal","required_args":[{"label":".GCT file","value":"","arg_name":"filepath","description":"No description :("}],"label":"Read .GCT File"}'''))
task_view.create()
# Out:
# Executing ...
# 	sys.path.insert(0, '/Users/kateme/ccal/')
# 	from ccal import read_gct as function
# Processing arguments ...
#
# 	Executing <function read_gct at 0x11a4901e0>:
# 		filepath = '/Users/kateme/discover/data/drug_sensitivity.out.SELECTED.gct' (<class 'str'>)

# %% [markdown]
# ## 3. Compare medulloblastoma expressional signatures to drug sensitivity data

# %% [markdown]
# ### 3.1 Compare CCLE hNSC signature to CTRP drug sensitivity

# %%
# !AUTOEXEC
# Make and show widget
task_view = task_manager.create_task_view(json.loads('''{"description":"","function_name":"make_association_panel","returns":[],"library_path":"/Users/kateme/ccal/","optional_args":[],"default_args":[],"library_name":"ccal.computational_cancer_biology.association","required_args":[{"label":"Comparison vector","value":"","arg_name":"target","description":"No description :("},{"label":"Comparison matrix","value":"","arg_name":"features","description":"No description :("},{"label":"Significance threshold","value":"","arg_name":"n_features","description":"No description :("},{"label":"Number of permutations","value":"","arg_name":"n_permutations","description":"No description :("}],"label":"Make Association Panel"}'''))
task_view.create()
# Out:
# Executing ...
# 	sys.path.insert(0, '/Users/kateme/ccal/')
# 	from ccal.computational_cancer_biology.association import make_association_panel as function
# Processing arguments ...
#
# 	Executing <function make_association_panel at 0x11a4d46a8>:
# 		features = ctrp_drug_sensitivity (<class 'pandas.core.frame.DataFrame'>)
# 		n_features = '0.9' (<class 'float'>)
# 		n_permutations = '2' (<class 'int'>)
# 		target = ccle_signatures_hNSC150 (<class 'pandas.core.series.Series'>)
# <094535> Target (735 cols) and features (645 cols) have 550 shared columns.
# <094535> Dropping features with less than 2 unique values ...
# <094535> 	Kept 481 features.
# <094535> Scoring (n_jobs=1) ...
# <094539> Computing 0.95 CI for using distributions built by 30 bootstraps ...
# <094556> Computing P-value & FDR by scoring against 2 permuted targets (n_jobs=1) ...
# [ForkPoolWorker-2] <094556> 	Scoring against permuted target (0/2) ...
# [ForkPoolWorker-2] <094559> 	Scoring against permuted target (1/2) ...
# <094602> 	Computing P-value and FDR ...
# <094602> Making annotations ...
# <094602> Plotting ...

# %%
# !AUTOEXEC
# Make and show widget
task_view = task_manager.create_task_view(json.loads('''{"description":"","function_name":"make_association_panel","returns":[],"library_path":"/Users/kateme/ccal/","optional_args":[],"default_args":[],"library_name":"ccal.computational_cancer_biology.association","required_args":[{"label":"Comparison vector","value":"","arg_name":"target","description":"No description :("},{"label":"Comparison matrix","value":"","arg_name":"features","description":"No description :("},{"label":"Significance threshold","value":"","arg_name":"n_features","description":"No description :("},{"label":"Number of permutations","value":"","arg_name":"n_permutations","description":"No description :("}],"label":"Make Association Panel"}'''))
task_view.create()
# Out:
# Executing ...
# 	sys.path.insert(0, '/Users/kateme/ccal/')
# 	from ccal.computational_cancer_biology.association import make_association_panel as function
# Processing arguments ...
#
# 	Executing <function make_association_panel at 0x11a4d46a8>:
# 		features = ctrp_drug_sensitivity (<class 'pandas.core.frame.DataFrame'>)
# 		n_features = '0.9' (<class 'float'>)
# 		n_permutations = '2' (<class 'int'>)
# 		target = ccle_signatures_hNSC150 (<class 'pandas.core.series.Series'>)
# <095755> Target (735 cols) and features (645 cols) have 550 shared columns.
# <095755> Dropping features with less than 2 unique values ...
# <095755> 	Kept 481 features.
# <095755> Scoring (n_jobs=1) ...
# <095801> Computing 0.95 CI for using distributions built by 30 bootstraps ...
# <095820> Computing P-value & FDR by scoring against 2 permuted targets (n_jobs=1) ...
# [ForkPoolWorker-4] <095820> 	Scoring against permuted target (0/2) ...
# [ForkPoolWorker-4] <095824> 	Scoring against permuted target (1/2) ...
# <095827> 	Computing P-value and FDR ...
# <095828> Making annotations ...
# <095828> Plotting ...

# %%
# !AUTOEXEC
# Make and show widget
task_view = task_manager.create_task_view(json.loads('''{"description":"","function_name":"make_association_panel","returns":[],"library_path":"/Users/kateme/ccal/","optional_args":[],"default_args":[],"library_name":"ccal.computational_cancer_biology.association","required_args":[{"label":"Comparison vector","value":"","arg_name":"target","description":"No description :("},{"label":"Comparison matrix","value":"","arg_name":"features","description":"No description :("},{"label":"Significance threshold","value":"","arg_name":"n_features","description":"No description :("},{"label":"Number of permutations","value":"","arg_name":"n_permutations","description":"No description :("}],"label":"Make Association Panel"}'''))
task_view.create()

# %%
ccal.association.make_association_panel(ccle_signatures_hNSC150, ctrp_drug_sensitivity,
                                        n_permutations=40, features_ascending=True, 
                                        n_features=.90)

# %% [markdown]
# ### 3.2 Compare CCLE hNSC signature to CCLE drug sensitivity

# %%
ccal.association.make_association_panel(ccle_signatures_hNSC150,
                                        ccle_drug_sensitivity.ix, n_jobs=1, 
                                        n_permutations=40, features_ascending=True, 
                                        n_features=.8)

# %% [markdown]
# ### 3.3 Compare Sanger hNSC signature to Sanger drug sensitivity

# %%
ccal.association.make_association_panel(sanger_signatures_hNSC150, sanger_drug_sensitivity,
                                        n_permutations=40, features_ascending=True,
                                        n_features=.80)
